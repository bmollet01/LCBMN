# %% [markdown]
# # Figure 4 : Performance comparison

# %%
import sys
import os
from src.util import comparison_method

# %% [markdown]
# ## Data generation :
# Presented results

# %% [markdown]
# ## Classification :

# %%
comparison_method('classification', save=True)

# %% [markdown]
# ## Regression :

# %%
comparison_method('regression', save=True)
