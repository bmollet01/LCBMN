# %% [markdown]
# # Figure 7 : Substitution
#
# Results from the substitution study, the results that are presented are obtained with the python script [`src/substitution.py`]() and the argument `classification` or `regression`.

# %%
from src.util import substitution

# %% [markdown]
# ## Classification :

# %%
substitution('classification', save=True)

# %% [markdown]
# ## Regression :

# %%
substitution('regression', save=True)
