# %% [markdown]
# # Figure 3 : Capacity evaluation

# %%
from src.util import plot_capacity_evaluation, plot_nestimator

# %% [markdown]
# ## Classification :
#
# ### Performance vs. Number of estimator (proxy of capcity) :

# %%
plot_capacity_evaluation('classification', save=True)

# %% [markdown]
# ### Number of estimator to reach the performance of the AMN framework :

# %%
plot_nestimator('classification', save=True)

# %% [markdown]
# ## Regression :
#
# ### Performance vs. Number of estimator (proxy of capcity) :

# %%
plot_capacity_evaluation('regression', save=True)

# %% [markdown]
# ### Number of estimator to reach the performance of the AMN framework :

# %%
plot_nestimator('regression', save=True)
